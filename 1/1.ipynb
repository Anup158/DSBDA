# %%
import pandas as pd

# %%
df = pd.read_csv("Students data (1).csv")

# %%
print(df.dtypes)
# Out:
# ID                       int64
# class                   object
# gender                  object
# Age                      int64
# CGPA                   float64
# Algebra                  int64
# Calculus1                int64
# Calculus2                int64
# Statistics               int64
# Probability              int64
# Measure                  int64
# Functional_analysis      int64
# from1                   object
# from2                   object
# from3                   object
# from4                    int64
# y                        int64
# dtype: object

# %%
df
# Out:
#        ID class  gender  Age   CGPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male   21  73.47       64         81         87
# 1    1142     A  female   12  71.22       57         50         51
# 2    1143     A  female   22  74.56       47         48         71
# 3    1144     A  female   21  72.89       46         72         38
# 4    1145     A  female   21  70.11       49         45         63
# ..    ...   ...     ...  ...    ...      ...        ...        ...
# 100  1241     A  female    1  88.34       87         83         92
# 101  1242     B    male    1  89.84       98         77         95
# 102  1243     B    male   12  88.82       83         80         91
# 103  1244     A    male   21  86.60       92         82         91
# 104  1245     A    male   12  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# 0            60           74       71                   60     A     A     A
# ...

# %%
print(df.describe())
# Out:
#                 ID         Age        CGPA     Algebra   Calculus1  \
# count   105.000000  105.000000  105.000000  105.000000  105.000000
# mean   1193.000000   18.561905   81.433238   76.057143   71.961905
# std      30.454885    7.364055   25.347075   11.722618   12.197039
# min    1141.000000    1.000000   24.040000   46.000000   38.000000
# 25%    1167.000000   13.000000   78.390000   67.000000   64.000000
# 50%    1193.000000   21.000000   84.010000   76.000000   73.000000
# 75%    1219.000000   21.000000   87.300000   84.000000   80.000000
# max    1245.000000   41.000000  286.010000   98.000000  100.000000
#
#         Calculus2  Statistics  Probability     Measure  Functional_analysis  \
# count  105.000000  105.000000   105.000000  105.000000           105.000000
# mean    78.942857   85.133333    83.876190   80.761905            75.323810
# std     14.997326   10.269509    10.514363   10.296119            13.003324
# ...

# %%
print(df.groupby(by=['Age']).size())
# Out:
# Age
# 1      7
# 2      1
# 3      1
# 4      1
# 11     4
# 12    12
# 13     3
# 21    55
# 22     2
# 23     3
# 24     2
# 25     4
# 26     2
# 27     5
# 31     2
# 41     1
# dtype: int64

# %%
print(df.isna().sum())
# Out:
# ID                     0
# class                  0
# gender                 0
# Age                    0
# CGPA                   0
# Algebra                0
# Calculus1              0
# Calculus2              0
# Statistics             0
# Probability            0
# Measure                0
# Functional_analysis    0
# from1                  0
# from2                  0
# from3                  0
# from4                  0
# y                      0
# dtype: int64

# %%
print(df.isnull())
# Out:
#         ID  class  gender    Age   CGPA  Algebra  Calculus1  Calculus2  \
# 0    False  False   False  False  False    False      False      False
# 1    False  False   False  False  False    False      False      False
# 2    False  False   False  False  False    False      False      False
# 3    False  False   False  False  False    False      False      False
# 4    False  False   False  False  False    False      False      False
# ..     ...    ...     ...    ...    ...      ...        ...        ...
# 100  False  False   False  False  False    False      False      False
# 101  False  False   False  False  False    False      False      False
# 102  False  False   False  False  False    False      False      False
# 103  False  False   False  False  False    False      False      False
# 104  False  False   False  False  False    False      False      False
#
#      Statistics  Probability  Measure  Functional_analysis  from1  from2  \
# ...

# %%
print(type("Age"))
# Out:
# <class 'str'>

# %%
df['Age'] = df['Age'].astype(float)

# %%
print(df.describe())
# Out:
#                 ID         Age        CGPA     Algebra   Calculus1  \
# count   105.000000  105.000000  105.000000  105.000000  105.000000
# mean   1193.000000   18.561905   81.433238   76.057143   71.961905
# std      30.454885    7.364055   25.347075   11.722618   12.197039
# min    1141.000000    1.000000   24.040000   46.000000   38.000000
# 25%    1167.000000   13.000000   78.390000   67.000000   64.000000
# 50%    1193.000000   21.000000   84.010000   76.000000   73.000000
# 75%    1219.000000   21.000000   87.300000   84.000000   80.000000
# max    1245.000000   41.000000  286.010000   98.000000  100.000000
#
#         Calculus2  Statistics  Probability     Measure  Functional_analysis  \
# count  105.000000  105.000000   105.000000  105.000000           105.000000
# mean    78.942857   85.133333    83.876190   80.761905            75.323810
# std     14.997326   10.269509    10.514363   10.296119            13.003324
# ...

# %%
print(df.dtypes)
# Out:
# ID                       int64
# class                   object
# gender                  object
# Age                    float64
# CGPA                   float64
# Algebra                  int64
# Calculus1                int64
# Calculus2                int64
# Statistics               int64
# Probability              int64
# Measure                  int64
# Functional_analysis      int64
# from1                   object
# from2                   object
# from3                   object
# from4                    int64
# y                        int64
# dtype: object

# %%
print(df.sort_values('Age'))
# Out:
#        ID class  gender   Age    CGPA  Algebra  Calculus1  Calculus2  \
# 28   1169     A    male   1.0   24.04       73         80         85
# 50   1191     A    male   1.0   79.00       82         72         77
# 101  1242     B    male   1.0   89.84       98         77         95
# 100  1241     A  female   1.0   88.34       87         83         92
# 97   1238     A    male   1.0   91.14       98         90         98
# ..    ...   ...     ...   ...     ...      ...        ...        ...
# 89   1230     A    male  27.0  286.01       77         60         78
# 19   1160     A    male  27.0   76.46       67         73         64
# 74   1215     A  female  31.0   87.26       80         78         87
# 73   1214     A  female  31.0   84.11       79         48         85
# 59   1200     B    male  41.0   79.34       62         75         80
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
df = df.rename(columns={'Age': 'Year Old'})

# %%
print(df.sort_index())
# Out:
#        ID class  gender  Year Old   CGPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male      21.0  73.47       64         81         87
# 1    1142     A  female      12.0  71.22       57         50         51
# 2    1143     A  female      22.0  74.56       47         48         71
# 3    1144     A  female      21.0  72.89       46         72         38
# 4    1145     A  female      21.0  70.11       49         45         63
# ..    ...   ...     ...       ...    ...      ...        ...        ...
# 100  1241     A  female       1.0  88.34       87         83         92
# 101  1242     B    male       1.0  89.84       98         77         95
# 102  1243     B    male      12.0  88.82       83         80         91
# 103  1244     A    male      21.0  86.60       92         82         91
# 104  1245     A    male      12.0  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
df = df.reset_index()

# %%
print(df)
# Out:
#      index    ID class  gender  Year Old   CGPA  Algebra  Calculus1  \
# 0        0  1141     A    male      21.0  73.47       64         81
# 1        1  1142     A  female      12.0  71.22       57         50
# 2        2  1143     A  female      22.0  74.56       47         48
# 3        3  1144     A  female      21.0  72.89       46         72
# 4        4  1145     A  female      21.0  70.11       49         45
# ..     ...   ...   ...     ...       ...    ...      ...        ...
# 100    100  1241     A  female       1.0  88.34       87         83
# 101    101  1242     B    male       1.0  89.84       98         77
# 102    102  1243     B    male      12.0  88.82       83         80
# 103    103  1244     A    male      21.0  86.60       92         82
# 104    104  1245     A    male      12.0  93.71       93         97
#
#      Calculus2  Statistics  Probability  Measure  Functional_analysis from1  \
# ...

# %%
df
# Out:
#      index    ID class  gender  Year Old   CGPA  Algebra  Calculus1  \
# 0        0  1141     A    male      21.0  73.47       64         81
# 1        1  1142     A  female      12.0  71.22       57         50
# 2        2  1143     A  female      22.0  74.56       47         48
# 3        3  1144     A  female      21.0  72.89       46         72
# 4        4  1145     A  female      21.0  70.11       49         45
# ..     ...   ...   ...     ...       ...    ...      ...        ...
# 100    100  1241     A  female       1.0  88.34       87         83
# 101    101  1242     B    male       1.0  89.84       98         77
# 102    102  1243     B    male      12.0  88.82       83         80
# 103    103  1244     A    male      21.0  86.60       92         82
# 104    104  1245     A    male      12.0  93.71       93         97
#
#      Calculus2  Statistics  Probability  Measure  Functional_analysis from1  \
# ...
